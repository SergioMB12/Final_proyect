# %%
import pandas as pd
import numpy as np
import unicodedata
pd.set_option('display.max_columns', None)

# %%
players=pd.read_csv('Player_Attributes.csv') #import de mi dataset
players= pd.DataFrame(players) #primera visualización de la cabeza del dataframe
players.sort_values("date",ascending=True, inplace=True)
#list(players[players["player_api_id"]==39901]["player_fifa_api_id"])[0]

# %%
players['date'] = pd.to_datetime(players['date'])
players['year'] = players['date'].dt.year
players = players.drop(columns = [ 'id','date'])
players = players.drop_duplicates(subset=['year','player_api_id'], keep='last')

# %%
players.columns
# Out:
# Index(['player_fifa_api_id', 'player_api_id', 'overall_rating', 'potential',
#        'preferred_foot', 'attacking_work_rate', 'defensive_work_rate',
#        'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'free_kick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year'],
#       dtype='object')

# %%
players.sample(5)
# Out:
#         player_fifa_api_id  player_api_id  overall_rating  potential  \
# 22798               165735          35442            71.0       74.0
# 41868               211204         410359            68.0       79.0
# 76715               170632          32584            62.0       72.0
# 138143              200055         164852            72.0       85.0
# 114294              148518          43313            64.0       64.0
#
#        preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 22798            left                None                   0      18.0
# 41868            left                high              medium      68.0
# 76715           right              medium              medium      11.0
# 138143          right                high              medium      75.0
# 114294          right              medium              medium      25.0
#
#         finishing  heading_accuracy  short_passing  volleys  dribbling  curve  \
# ...

# %%
names=pd.read_csv('Player.csv') #import de mi dataset

names = pd.DataFrame(names) #primera visualización de la cabeza del dataframe

names.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
#names[names["player_fifa_api_id"]==20801]

# %%
#names[names["player_api_id"]==155782].head()

# %%
#nlist = list(names.player_name.unique())
#len(nlist)

# %%
#%pip install fuzzywuzzy

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /home/sergiooo/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#for e in pblist:
    #print(e , process.extractOne(e ,nlist))

# %%
#dict_names = {}
#err = []
#for e in names.player_name:
    #result = process.extractOne(e ,players_big.player)
    #if int (result[1])>93:
        #dict_names[e]=result[0]
        #print(dict_names[e])
    #else:
        #err.append(e)
#print(dict_names)

# %%
#type(result)

# %%
#players_big[['player_a_matched', 'fuzz_score_a']] = players_big.player.apply(lambda x: process.extractOne(x,names.player_name.tolist(),scorer = fuzz.partial_ratio)).apply(pd.Series)

# %%
clubsbien = ['KRC Genk', 'Beerschot AC', 'SV Zulte-Waregem', 'Sporting Lokeren',
       'KSV Cercle Brugge', 'RSC Anderlecht', 'KAA Gent', 'RAEC Mons',
       'FCV Dender EH', 'Standard de Liège', 'KV Mechelen',
       'Club Brugge KV', 'KSV Roeselare', 'KV Kortrijk', 'Tubize',
       'Royal Excel Mouscron', 'KVC Westerlo', 'Sporting Charleroi',
       'Sint-Truidense VV', 'Lierse SK', 'KAS Eupen',
       'Oud-Heverlee Leuven', 'Waasland-Beveren', 'KV Oostende',
       'Manchester United', 'Newcastle United', 'Arsenal',
       'West Bromwich Albion', 'Sunderland', 'Liverpool',
       'West Ham United', 'Wigan Athletic', 'Aston Villa',
       'Manchester City', 'Everton', 'Blackburn Rovers', 'Middlesbrough',
       'Tottenham Hotspur', 'Bolton Wanderers', 'Stoke City', 'Hull City',
       'Fulham', 'Chelsea', 'Portsmouth', 'Birmingham City',
       'Wolverhampton Wanderers', 'Burnley', 'Blackpool', 'Swansea City',
       'Queens Park Rangers', 'Norwich City', 'Southampton', 'Reading',
       'Crystal Palace', 'Cardiff City', 'Leicester City', 'Bournemouth',
       'Watford', 'AJ Auxerre', 'FC Nantes', 'Girondins de Bordeaux',
       'SM Caen', 'Le Havre AC', 'OGC Nice', 'Le Mans FC', 'FC Lorient',
       'Olympique Lyonnais', 'Toulouse FC', 'AS Monaco',
       'Paris Saint-Germain', 'AS Nancy-Lorraine', 'LOSC Lille',
       'Stade Rennais FC', 'Olympique de Marseille',
       'FC Sochaux-Montbéliard', 'Grenoble Foot 38', 'Valenciennes FC',
       'AS Saint-Étienne', 'RC Lens', 'Montpellier Hérault SC',
       "US Boulogne Cote D'Opale", 'AC Arles-Avignon',
       'Stade Brestois 29', 'AC Ajaccio', 'Évian Thonon Gaillard FC',
       'Dijon FCO', 'Stade de Reims', 'SC Bastia', 'ES Troyes AC',
       'En Avant de Guingamp', 'FC Metz', 'Angers SCO', 'GFC Ajaccio',
       'FC Bayern Munich', 'Hamburger SV', 'Bayer 04 Leverkusen',
       'Borussia Dortmund', 'FC Schalke 04', 'Hannover 96',
       'VfL Wolfsburg', '1. FC Köln', 'Eintracht Frankfurt',
       'Hertha BSC Berlin', 'DSC Arminia Bielefeld', 'SV Werder Bremen',
       'FC Energie Cottbus', 'TSG 1899 Hoffenheim',
       'Borussia Mönchengladbach', 'VfB Stuttgart', 'Karlsruher SC',
       'VfL Bochum', 'SC Freiburg', '1. FC Nürnberg', '1. FSV Mainz 05',
       '1. FC Kaiserslautern', 'FC St. Pauli', 'FC Augsburg',
       'Fortuna Düsseldorf', 'SpVgg Greuther Fürth',
       'Eintracht Braunschweig', 'SC Paderborn 07', 'FC Ingolstadt 04',
       'SV Darmstadt 98', 'Atalanta', 'Siena', 'Cagliari', 'Lazio',
       'Catania', 'Genoa', 'Chievo Verona', 'Reggio Calabria',
       'Fiorentina', 'Juventus', 'Milan', 'Bologna', 'Roma', 'Napoli',
       'Sampdoria', 'Inter', 'Torino', 'Lecce', 'Udinese', 'Palermo',
       'Bari', 'Livorno', 'Parma', 'Cesena', 'Brescia', 'Novara',
       'Pescara', 'Hellas Verona', 'Sassuolo', 'Empoli', 'Frosinone',
       'Carpi', 'Vitesse', 'FC Groningen', 'Roda JC Kerkrade',
       'FC Twente', 'Willem II', 'Ajax', 'N.E.C.', 'De Graafschap',
       'FC Utrecht', 'PSV', 'Heracles Almelo', 'Feyenoord',
       'Sparta Rotterdam', 'ADO Den Haag', 'FC Volendam', 'SC Heerenveen',
       'AZ', 'NAC Breda', 'RKC Waalwijk', 'VVV-Venlo', 'Excelsior',
       'PEC Zwolle', 'SC Cambuur', 'Go Ahead Eagles', 'FC Dordrecht',
       'Wisła Kraków', 'Polonia Bytom', 'Ruch Chorzów', 'Legia Warszawa',
       'P. Warszawa', 'Śląsk Wrocław', 'Lechia Gdańsk', 'Widzew Łódź',
       'Odra Wodzisław', 'Lech Poznań', 'GKS Bełchatów', 'Arka Gdynia',
       'Jagiellonia Białystok', 'Piast Gliwice', 'Cracovia',
       'Korona Kielce', 'Zagłębie Lubin', 'Podbeskidzie Bielsko-Biała',
       'Pogoń Szczecin', 'Zawisza Bydgoszcz', 'Górnik Łęczna',
       'Termalica Bruk-Bet Nieciecza', 'FC Porto', 'CF Os Belenenses',
       'Sporting CP', 'Trofense', 'Vitória Guimarães', 'Vitória Setúbal',
       'FC Paços de Ferreira', 'SC Braga', 'Amadora',
       'Académica de Coimbra', 'Rio Ave FC', 'SL Benfica', 'Leixões SC',
       'CD Nacional', 'Naval 1° de Maio', 'CS Marítimo',
       'União de Leiria, SAD', 'S.C. Olhanense', 'Portimonense',
       'SC Beira Mar', 'Feirense', 'Gil Vicente FC', 'Moreirense FC',
       'Estoril Praia', 'FC Arouca', 'FC Penafiel', 'Boavista FC',
       'Uniao da Madeira', 'Tondela', 'Falkirk', 'Rangers',
       'Heart of Midlothian', 'Motherwell', 'Kilmarnock', 'Hibernian',
       'Aberdeen', 'Inverness Caledonian Thistle', 'Celtic', 'St. Mirren',
       'Hamilton Academical FC', 'Dundee United', 'St. Johnstone FC',
       'Dunfermline Athletic', 'Dundee FC', 'Ross County FC',
       'Partick Thistle F.C.', 'Valencia CF', 'RCD Mallorca',
       'CA Osasuna', 'Villarreal CF', 'RC Deportivo de La Coruña',
       'Real Madrid CF', 'CD Numancia', 'FC Barcelona',
       'Racing Santander', 'Sevilla FC', 'Real Sporting de Gijón',
       'Getafe CF', 'Real Betis Balompié', 'RC Recreativo',
       'RCD Espanyol', 'Real Valladolid', 'Athletic Club de Bilbao',
       'UD Almería', 'Atlético Madrid', 'Málaga CF',
       'Xerez Club Deportivo', 'Real Zaragoza', 'CD Tenerife',
       'Hércules Club de Fútbol', 'Levante UD', 'Real Sociedad',
       'Granada CF', 'Rayo Vallecano', 'RC Celta de Vigo', 'Elche CF',
       'SD Eibar', 'Córdoba CF', 'UD Las Palmas',
       'Grasshopper Club Zürich', 'AC Bellinzona', 'BSC Young Boys',
       'FC Basel', 'FC Aarau', 'FC Sion', 'FC Luzern', 'FC Vaduz',
       'Neuchâtel Xamax', 'FC Zürich', 'FC St. Gallen', 'FC Thun',
       'Servette FC', 'FC Lausanne-Sports', 'Lugano']

# %%
def limpia(a):
    if '+' in str(a):
        return float(str(a).split('+')[0])
    elif '-' in str(a):
        return float(str(a).split('-')[0])
    else:
        return float(a)

# %%
def elimina_tildes(cadena):
    s = ''.join((c for c in unicodedata.normalize('NFD',cadena) if unicodedata.category(c) != 'Mn'))
    return s

# %%
def super_limpia(a):
    try:
        return int(a)
    except:
        return np.nan

# %%
f17=pd.read_csv('players_17.csv') #import de mi dataset

# %%
f17.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   31  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   29  1987-06-24
# 2             Neymar        Neymar da Silva Santos Junior   24  1992-02-05
# 3           M. Neuer                         Manuel Neuer   30  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   29  1987-01-24
#
#    height_cm  weight_kg nationality               club  overall  potential  \
# ...

# %%
f17['year'] = 2017
f17=f17[f17['club'].isin(clubsbien)]

f17 = f17.drop(columns = [ 'player_url','club', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
                          'nationality', 'value_eur', 'wage_eur', 'player_positions', 
                           'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'mentality_composure', 
                          'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number',
                          'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'gk_diving', 'gk_handling', 'gk_kicking', 
                          'gk_reflexes', 'gk_speed', 'gk_positioning','player_traits', 'pace', 'shooting', 'passing', 'dribbling',
                          'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm',
                          'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'])

f17.columns = ['player_api_id', 'name','overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
                     'defensive_work_rate', 'crossing', 'finishing',
                     'heading_accuracy', 'short_passing', 'volleys', 
                     'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 
                     'ball_control', 'acceleration', 'sprint_speed', 'agility', 
                     'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 
                     'strength', 'long_shots', 'aggression', 'interceptions', 
                     'positioning', 'vision', 'penalties', 'marking', 'standing_tackle',
                     'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes','year']

f17['name'].apply(elimina_tildes)

for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f17[i] = f17[i].apply(limpia)
        

                
for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f17[i] = f17[i].apply(super_limpia)

# %%
f18=pd.read_csv('players_18.csv') #import de mi dataset

# %%
f18['year'] = 2018
f18=f18[f18['club'].isin(clubsbien)]

f18 = f18.drop(columns = [ 'player_url','club', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
                          'nationality', 'value_eur', 'wage_eur', 'player_positions', 
                           'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'mentality_composure', 
                          'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number',
                          'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'gk_diving', 'gk_handling', 'gk_kicking', 
                          'gk_reflexes', 'gk_speed', 'gk_positioning','player_traits', 'pace', 'shooting', 'passing', 'dribbling',
                          'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm',
                          'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'])

f18.columns = ['player_api_id', 'name','overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
                     'defensive_work_rate', 'crossing', 'finishing',
                     'heading_accuracy', 'short_passing', 'volleys', 
                     'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 
                     'ball_control', 'acceleration', 'sprint_speed', 'agility', 
                     'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 
                     'strength', 'long_shots', 'aggression', 'interceptions', 
                     'positioning', 'vision', 'penalties', 'marking', 'standing_tackle',
                     'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes','year']

f18['name'].apply(elimina_tildes)



for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f18[i] = f18[i].apply(limpia)


        
for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f18[i] = f18[i].apply(super_limpia)

# %%
f19=pd.read_csv('players_19.csv') #import de mi dataset

# %%
f19['year'] = 2019
f19=f19[f19['club'].isin(clubsbien)]

f19 = f19.drop(columns = [ 'player_url','club', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
                          'nationality', 'value_eur', 'wage_eur', 'player_positions', 
                           'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'mentality_composure', 
                          'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number',
                          'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'gk_diving', 'gk_handling', 'gk_kicking', 
                          'gk_reflexes', 'gk_speed', 'gk_positioning','player_traits', 'pace', 'shooting', 'passing', 'dribbling',
                          'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm',
                          'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'])

f19.columns = ['player_api_id', 'name','overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
                     'defensive_work_rate', 'crossing', 'finishing',
                     'heading_accuracy', 'short_passing', 'volleys', 
                     'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 
                     'ball_control', 'acceleration', 'sprint_speed', 'agility', 
                     'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 
                     'strength', 'long_shots', 'aggression', 'interceptions', 
                     'positioning', 'vision', 'penalties', 'marking', 'standing_tackle',
                     'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes','year']

f19['name'].apply(elimina_tildes)


for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f19[i] = f19[i].apply(limpia)


        
for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f19[i] = f19[i].apply(super_limpia)

# %%
f20=pd.read_csv('players_20.csv') #import de mi dataset

# %%
f20['year'] = 2020
f20=f20[f20['club'].isin(clubsbien)]

f20 = f20.drop(columns = [ 'player_url','club', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg',
                          'nationality', 'value_eur', 'wage_eur', 'player_positions', 
                           'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'mentality_composure', 
                          'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number',
                          'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'gk_diving', 'gk_handling', 'gk_kicking', 
                          'gk_reflexes', 'gk_speed', 'gk_positioning','player_traits', 'pace', 'shooting', 'passing', 'dribbling',
                          'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm',
                          'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'])

f20.columns = ['player_api_id', 'name','overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate',
                     'defensive_work_rate', 'crossing', 'finishing',
                     'heading_accuracy', 'short_passing', 'volleys', 
                     'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 
                     'ball_control', 'acceleration', 'sprint_speed', 'agility', 
                     'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 
                     'strength', 'long_shots', 'aggression', 'interceptions', 
                     'positioning', 'vision', 'penalties', 'marking', 'standing_tackle',
                     'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes','year']

f20['name'].apply(elimina_tildes)



for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f20[i] = f20[i].apply(limpia)


for i in ['overall_rating', 'potential', 
            'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
        f20[i] = f20[i].apply(super_limpia)

# %%
print(list(f18.columns))
print(len(list(f18.columns)))
print(list(f19.columns))
print(len(list(f19.columns)))
print(list(f20.columns))
print(len(list(f20.columns)))
# Out:
# ['player_api_id', 'name', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year']
# 41
# ...

# %%
names.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
names = names.drop(columns = [ 'id','player_fifa_api_id','birthday','height','weight'])
names.head()
# Out:
#    player_api_id         player_name
# 0         505942  Aaron Appindangoye
# 1         155782     Aaron Cresswell
# 2         162549         Aaron Doran
# 3          30572       Aaron Galindo
# 4          23780        Aaron Hughes

# %%
players_names = names.merge(players, on='player_api_id', how='left')
players_names = players_names.drop(columns = ['player_fifa_api_id'])
players_names.columns = ['player_api_id', 'name', 'overall_rating', 'potential',
       'preferred_foot', 'attacking_work_rate', 'defensive_work_rate',
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'dribbling', 'curve', 'free_kick_accuracy', 'long_passing',
       'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
       'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
       'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
       'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
       'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year']
players_names['name'].apply(elimina_tildes)
# Out:
# 0        Aaron Appindangoye
# 1        Aaron Appindangoye
# 2        Aaron Appindangoye
# 3           Aaron Cresswell
# 4           Aaron Cresswell
#                 ...
# 73054    Zvjezdan Misimovic
# 73055    Zvjezdan Misimovic
# 73056    Zvjezdan Misimovic
# 73057    Zvjezdan Misimovic
# 73058    Zvjezdan Misimovic
# Name: name, Length: 73059, dtype: object

# %%
def super_limpia(a):
    try:
        return int(a)
    except:
        return np.nan

for i in ['overall_rating', 'potential', 
            'crossing', 'finishing', 
            'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
            'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 
            'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 
            'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 
            'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']:
   
    players_names[i] = players_names[i].apply(super_limpia)

# %%
players_names.head()
# Out:
#    player_api_id                name  overall_rating  potential  \
# 0         505942  Aaron Appindangoye            61.0       65.0
# 1         505942  Aaron Appindangoye            67.0       71.0
# 2         505942  Aaron Appindangoye            67.0       71.0
# 3         155782     Aaron Cresswell            53.0       60.0
# 4         155782     Aaron Cresswell            53.0       60.0
#
#   preferred_foot attacking_work_rate defensive_work_rate  crossing  finishing  \
# 0          right              medium              medium      48.0       43.0
# 1          right              medium              medium      49.0       44.0
# 2          right              medium              medium      49.0       44.0
# 3          right              medium              medium      22.0       48.0
# 4          right              medium              medium      22.0       48.0
#
#    heading_accuracy  short_passing  volleys  dribbling  curve  \
# ...

# %%
print(list(f17.columns))
print(len(list(f17.columns)))
# Out:
# ['player_api_id', 'name', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year']
# 41

# %%
print(list(players_names.columns))
print(len(list(players_names.columns)))
# Out:
# ['player_api_id', 'name', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year']
# 41

# %%
rompe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6938/1163341432.py in <module>
# ----> 1 rompe
#
# NameError: name 'rompe' is not defined

# %%
players_names1 = players_names[players_names['year'] == 2016]

# %%
players_names1
# Out:
#        player_api_id                name  overall_rating  potential  \
# 2             505942  Aaron Appindangoye            67.0       71.0
# 12            155782     Aaron Cresswell            74.0       76.0
# 21            162549         Aaron Doran            65.0       67.0
# 31             30572       Aaron Galindo            69.0       69.0
# 50             27316          Aaron Hunt            77.0       77.0
# ...              ...                 ...             ...        ...
# 72970          42860    Zlatko Junuzovic            78.0       78.0
# 72993         107281      Zoltan Stieber            73.0       74.0
# 73016          99031         Zoran Tosic            79.0       79.0
# 73020         192132  Zouhaier Dhaouadhi            64.0       64.0
# 73027         282473      Zouhair Feddal            75.0       76.0
#
#       preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 2              right              medium              medium      49.0
# ...

# %%
f17[['player_a_matched', 'fuzz_score_a']] = f17.name.apply(lambda x: process.extractOne(x,
                                                                                        players_names1.name.tolist(),
                                                                                        scorer = fuzz.partial_ratio)).apply(pd.Series)

# %%
f17.sample(20)
# Out:
#        player_api_id            name  overall_rating  potential  \
# 16512         235018      M. Nicolas              52         70
# 6126          177906      D. Soddimo              69         69
# 3618          146510          Corona              72         72
# 763           210679  Paulo Oliveira              78         82
# 3525          193690    Z. Tomašević              72         73
# 1224          212541     L. Vangioni              77         77
# 3621          148526      P. Kieszek              72         72
# 7808          210314        I. Azemi              67         69
# 9928          229662      M. Polaček              65         67
# 1248          227928   Nélson Semedo              76         85
# 13709         200742     B. Heneghan              60         68
# 16498         227770        M. Boney              52         71
# 16525         231816     C. Trachsel              52         68
# 139           193352    R. Rodríguez              83         86
# ...

# %%
f20[['player_a_matched', 'fuzz_score_a']] = f19.name.apply(lambda x: process.extractOne(x,
                                                                                        f19.player_a_matched.tolist(),
                                                                                        scorer = fuzz.partial_ratio)).apply(pd.Series)

# %%
f20 = f20[f20['fuzz_score_a'] > 80]

# %%
f19 = f19[f19['fuzz_score_a'] > 80]

# %%
f18 = f18[f18['fuzz_score_a'] > 80]

# %%
f17 = f17[f17['fuzz_score_a'] > 80]

# %%
f17.rename(columns={'player_a_matched': 'name'}, inplace=True)
f18.rename(columns={'player_a_matched': 'name'}, inplace=True) 
f19.rename(columns={'player_a_matched': 'name'}, inplace=True) 
f20.rename(columns={'player_a_matched': 'name'}, inplace=True)
# Out:
# /home/sergiooo/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
columnasminiconfusion = ['player_api_id', 'borrar', 'overall_rating', 'potential',
       'preferred_foot', 'attacking_work_rate', 'defensive_work_rate',
       'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'dribbling', 'curve', 'free_kick_accuracy', 'long_passing',
       'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
       'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
       'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
       'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
       'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year',
       'name', 'fuzz_score_a']
f17.columns= columnasminiconfusion
f18.columns= columnasminiconfusion
f19.columns= columnasminiconfusion
f20.columns= columnasminiconfusion

# %%
f17 = f17.drop(columns = ['borrar','fuzz_score_a'])
f18 = f18.drop(columns = ['borrar','fuzz_score_a'])
f19 = f19.drop(columns = ['borrar','fuzz_score_a'])
f20 = f20.drop(columns = ['borrar','fuzz_score_a'])

# %%
f17
# Out:
#        player_api_id  overall_rating  potential preferred_foot  \
# 2             190871              92         95          Right
# 5             193080              90         92          Right
# 14            164240              89         89          Right
# 17            194765              88         92           Left
# 18            192985              88         91          Right
# ...              ...             ...        ...            ...
# 16770         231375              51         59          Right
# 16797         230000              50         72          Right
# 16804         233229              50         69           Left
# 16814         235101              50         67          Right
# 16853         233481              50         62          Right
#
#        attacking_work_rate  defensive_work_rate  crossing  finishing  \
# 2                     30.0                 56.0        75         89
# ...

# %%
ftotal = pd.concat([f20,f19])

# %%
ftotal = pd.concat([ftotal,f18])

# %%
ftotal = pd.concat([ftotal,f17])

# %%
ftotal.columns
# Out:
# Index(['player_api_id', 'overall_rating', 'potential', 'preferred_foot',
#        'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing',
#        'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
#        'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
#        'interceptions', 'positioning', 'vision', 'penalties', 'marking',
#        'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
#        'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year', 'name'],
#       dtype='object')

# %%
ftotal =pd.concat([ftotal,players_names])
ftotal
# Out:
#        player_api_id                   name  overall_rating  potential  \
# 0             158023                  Naldo            94.0       94.0
# 2             190871                 Neymar            92.0       92.0
# 3             200389           David De Gea            91.0       93.0
# 15            215914                   Alan            89.0       90.0
# 16            138956  Marc-Andre ter Stegen            89.0       89.0
# ...              ...                    ...             ...        ...
# 73054          39902     Zvjezdan Misimovic            77.0       80.0
# 73055          39902     Zvjezdan Misimovic            83.0       85.0
# 73056          39902     Zvjezdan Misimovic            83.0       85.0
# 73057          39902     Zvjezdan Misimovic            81.0       81.0
# 73058          39902     Zvjezdan Misimovic            78.0       78.0
#
#       preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# ...

# %%
new_cols = ['player_api_id','name', 'overall_rating', 'potential', 'preferred_foot',
       'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing',
       'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve',
       'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration',
       'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
       'jumping', 'stamina', 'strength', 'long_shots', 'aggression',
       'interceptions', 'positioning', 'vision', 'penalties', 'marking',
       'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling',
       'gk_kicking', 'gk_positioning', 'gk_reflexes', 'year']

# %%
ftotal=ftotal[new_cols]
ftotal
# Out:
#        player_api_id                    name  overall_rating  potential  \
# 0             158023                   Naldo              94         94
# 2             190871                  Neymar              92         92
# 3             200389            David De Gea              91         93
# 15            215914                    Alan              89         90
# 16            138956   Marc-Andre ter Stegen              89         89
# ...              ...                     ...             ...        ...
# 16770         231375                   Diney              51         59
# 16797         230000      Jussi Jaaskelainen              50         72
# 16804         233229  Christopher McLaughlin              50         69
# 16814         235101        Michal Markowski              50         67
# 16853         233481            Andrea Rossi              50         62
#
#       preferred_foot  attacking_work_rate  defensive_work_rate  crossing  \
# ...

# %%
f19
# Out:
#        player_api_id  overall_rating  potential preferred_foot  \
# 0              20801              94         94          Right
# 2             190871              92         93          Right
# 3             193080              91         93          Right
# 4             192985              91         92          Right
# 8             183277              91         91          Right
# ...              ...             ...        ...            ...
# 17342         244712              52         67           Left
# 17351         240822              52         66          Right
# 17465         233727              51         71          Right
# 17536         229615              51         63          Right
# 17582         238758              50         76          Right
#
#        attacking_work_rate  defensive_work_rate  crossing  finishing  \
# 0                     35.0                 79.0        84         94
# ...

# %%
f19.to_csv("f19_final.csv",index=False) 
f18.to_csv("f18_final.csv",index=False)

# %%
ftotal.agility.mean()
# Out:
# 64.90250930790025

# %%
ftotal.agility.max()
# Out:
# 96.0

# %%
ftotal.agility.min()
# Out:
# 11.0
